# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt

# %%
# Set the directories for the training and validation datasets
train_dir = 'Dataset/train'
val_dir = 'Dataset/test'

# %%
# Set the parameters for the image preprocessing
img_width, img_height = 224, 224
batch_size = 32

# %%
# Create data generators to preprocess the images
train_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True)
val_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    target_size=(img_width, img_height),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')
# Out:
# Found 375 images belonging to 35 classes.

# %%
val_generator = val_datagen.flow_from_directory(val_dir,
                                                target_size=(img_width, img_height),
                                                batch_size=batch_size,
                                                class_mode='categorical')
# Out:
# Found 109 images belonging to 35 classes.

# %%
# Define the CNN architecture
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_width, img_height, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(35, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 86528)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               11075712
# _________________________________________________________________
# dense_1 (Dense)              (None, 35)                4515
# =================================================================
# Total params: 11,173,475
# Trainable params: 11,173,475
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train the model
epochs = 100
history = model.fit(train_generator,
                    epochs=epochs,
                    validation_data=val_generator)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 25s 2s/step - loss: 4.1852 - accuracy: 0.0133 - val_loss: 3.5510 - val_accuracy: 0.0367
# Epoch 2/100
# 12/12 [==============================] - 25s 2s/step - loss: 3.5505 - accuracy: 0.0427 - val_loss: 3.5373 - val_accuracy: 0.0734
# Epoch 3/100
# 12/12 [==============================] - 26s 2s/step - loss: 3.5395 - accuracy: 0.0533 - val_loss: 3.4872 - val_accuracy: 0.1101
# Epoch 4/100
# 12/12 [==============================] - 25s 2s/step - loss: 3.4843 - accuracy: 0.0827 - val_loss: 3.3091 - val_accuracy: 0.0826
# Epoch 5/100
# 12/12 [==============================] - 25s 2s/step - loss: 3.3950 - accuracy: 0.0773 - val_loss: 3.1310 - val_accuracy: 0.1376
# Epoch 6/100
# 12/12 [==============================] - 25s 2s/step - loss: 3.2139 - accuracy: 0.1733 - val_loss: 2.9512 - val_accuracy: 0.2018
# Epoch 7/100
# 12/12 [==============================] - 25s 2s/step - loss: 2.9752 - accuracy: 0.2160 - val_loss: 2.6806 - val_accuracy: 0.3119
# Epoch 8/100
# 12/12 [==============================] - 25s 2s/step - loss: 2.7638 - accuracy: 0.2320 - val_loss: 2.5107 - val_accuracy: 0.3211
# Epoch 9/100
# 12/12 [==============================] - 26s 2s/step - loss: 2.5975 - accuracy: 0.2587 - val_loss: 2.6020 - val_accuracy: 0.3028
# Epoch 10/100
# 12/12 [==============================] - 26s 2s/step - loss: 2.3615 - accuracy: 0.3440 - val_loss: 2.0118 - val_accuracy: 0.4404
# Epoch 11/100
# 12/12 [==============================] - 26s 2s/step - loss: 2.1750 - accuracy: 0.3840 - val_loss: 1.8701 - val_accuracy: 0.4495
# Epoch 12/100
# 12/12 [==============================] - 26s 2s/step - loss: 1.7789 - accuracy: 0.4933 - val_loss: 1.6354 - val_accuracy: 0.4862
# Epoch 13/100
# 12/12 [==============================] - 26s 2s/step - loss: 1.5740 - accuracy: 0.5413 - val_loss: 1.2930 - val_accuracy: 0.6330
# Epoch 14/100
# 12/12 [==============================] - 26s 2s/step - loss: 1.3665 - accuracy: 0.6267 - val_loss: 1.0972 - val_accuracy: 0.6972
# Epoch 15/100
# 12/12 [==============================] - 26s 2s/step - loss: 1.1209 - accuracy: 0.6933 - val_loss: 1.2375 - val_accuracy: 0.6239
# Epoch 16/100
# 12/12 [==============================] - 26s 2s/step - loss: 0.9460 - accuracy: 0.7280 - val_loss: 0.7408 - val_accuracy: 0.7706
# Epoch 17/100
# 12/12 [==============================] - 26s 2s/step - loss: 0.8054 - accuracy: 0.7627 - val_loss: 0.6271 - val_accuracy: 0.8349
# Epoch 18/100
# 12/12 [==============================] - 27s 2s/step - loss: 0.8061 - accuracy: 0.7680 - val_loss: 0.5068 - val_accuracy: 0.8716
# Epoch 19/100
# 12/12 [==============================] - 26s 2s/step - loss: 0.8355 - accuracy: 0.7893 - val_loss: 0.5539 - val_accuracy: 0.8440
# Epoch 20/100
# 12/12 [==============================] - 25s 2s/step - loss: 0.7183 - accuracy: 0.7787 - val_loss: 0.3199 - val_accuracy: 0.9358
# Epoch 21/100
# 12/12 [==============================] - 25s 2s/step - loss: 0.6820 - accuracy: 0.7947 - val_loss: 0.5666 - val_accuracy: 0.8991
# Epoch 22/100
# 12/12 [==============================] - 24s 2s/step - loss: 0.4851 - accuracy: 0.8667 - val_loss: 0.4760 - val_accuracy: 0.8532
# Epoch 23/100
# 12/12 [==============================] - 23s 2s/step - loss: 0.3392 - accuracy: 0.8987 - val_loss: 0.4313 - val_accuracy: 0.8991
# Epoch 24/100
# 12/12 [==============================] - 25s 2s/step - loss: 0.3738 - accuracy: 0.8933 - val_loss: 0.2109 - val_accuracy: 0.9266
# Epoch 25/100
# 12/12 [==============================] - 25s 2s/step - loss: 0.3444 - accuracy: 0.8933 - val_loss: 0.1790 - val_accuracy: 0.9725
# Epoch 26/100
# 12/12 [==============================] - 24s 2s/step - loss: 0.2960 - accuracy: 0.8880 - val_loss: 0.2475 - val_accuracy: 0.9358
# Epoch 27/100
# 12/12 [==============================] - 24s 2s/step - loss: 0.2815 - accuracy: 0.9280 - val_loss: 0.2370 - val_accuracy: 0.9083
# Epoch 28/100
# 12/12 [==============================] - 25s 2s/step - loss: 0.2163 - accuracy: 0.9467 - val_loss: 0.1397 - val_accuracy: 0.9541
# Epoch 29/100
# 12/12 [==============================] - 25s 2s/step - loss: 0.2559 - accuracy: 0.9387 - val_loss: 0.2405 - val_accuracy: 0.9450
# Epoch 30/100
# 12/12 [==============================] - 26s 2s/step - loss: 0.3622 - accuracy: 0.9120 - val_loss: 0.1445 - val_accuracy: 0.9450
# Epoch 31/100
# 12/12 [==============================] - 26s 2s/step - loss: 0.2637 - accuracy: 0.9360 - val_loss: 0.0765 - val_accuracy: 0.9817
# Epoch 32/100
# 12/12 [==============================] - 25s 2s/step - loss: 0.2190 - accuracy: 0.9493 - val_loss: 0.2204 - val_accuracy: 0.9266
# Epoch 33/100
# 12/12 [==============================] - 26s 2s/step - loss: 0.2990 - accuracy: 0.9093 - val_loss: 0.1364 - val_accuracy: 0.9633
# Epoch 34/100
# 12/12 [==============================] - 24s 2s/step - loss: 0.2355 - accuracy: 0.9360 - val_loss: 0.0776 - val_accuracy: 0.9817
# Epoch 35/100
# 12/12 [==============================] - 25s 2s/step - loss: 0.1927 - accuracy: 0.9413 - val_loss: 0.0850 - val_accuracy: 0.9725
# Epoch 36/100
# 12/12 [==============================] - 24s 2s/step - loss: 0.1545 - accuracy: 0.9600 - val_loss: 0.0191 - val_accuracy: 1.0000
# Epoch 37/100
# 12/12 [==============================] - 23s 2s/step - loss: 0.1251 - accuracy: 0.9680 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 38/100
# 12/12 [==============================] - 26s 2s/step - loss: 0.1388 - accuracy: 0.9733 - val_loss: 0.0219 - val_accuracy: 0.9908
# Epoch 39/100
# 12/12 [==============================] - 25s 2s/step - loss: 0.0999 - accuracy: 0.9707 - val_loss: 0.0651 - val_accuracy: 0.9725
# Epoch 40/100
# 12/12 [==============================] - 25s 2s/step - loss: 0.1298 - accuracy: 0.9627 - val_loss: 0.0132 - val_accuracy: 1.0000
# Epoch 41/100
# 12/12 [==============================] - 24s 2s/step - loss: 0.0796 - accuracy: 0.9680 - val_loss: 0.1325 - val_accuracy: 0.9633
# Epoch 42/100
# 12/12 [==============================] - 24s 2s/step - loss: 0.0787 - accuracy: 0.9680 - val_loss: 0.0286 - val_accuracy: 0.9908
# Epoch 43/100
# 12/12 [==============================] - 25s 2s/step - loss: 0.1113 - accuracy: 0.9733 - val_loss: 0.0779 - val_accuracy: 0.9908
# Epoch 44/100
# 12/12 [==============================] - 25s 2s/step - loss: 0.1813 - accuracy: 0.9493 - val_loss: 0.0335 - val_accuracy: 0.9908
# Epoch 45/100
# 12/12 [==============================] - 25s 2s/step - loss: 0.1146 - accuracy: 0.9680 - val_loss: 0.0400 - val_accuracy: 0.9908
# Epoch 46/100
# 12/12 [==============================] - 24s 2s/step - loss: 0.1257 - accuracy: 0.9707 - val_loss: 0.1255 - val_accuracy: 0.9541
# Epoch 47/100
# 12/12 [==============================] - 22s 2s/step - loss: 0.0832 - accuracy: 0.9787 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 48/100
# 12/12 [==============================] - 22s 2s/step - loss: 0.0703 - accuracy: 0.9813 - val_loss: 0.0089 - val_accuracy: 1.0000
# Epoch 49/100
# 12/12 [==============================] - 22s 2s/step - loss: 0.0979 - accuracy: 0.9760 - val_loss: 0.0320 - val_accuracy: 0.9908
# Epoch 50/100
# 12/12 [==============================] - 23s 2s/step - loss: 0.0688 - accuracy: 0.9813 - val_loss: 0.0616 - val_accuracy: 0.9817
# Epoch 51/100
# 12/12 [==============================] - 21s 2s/step - loss: 0.0715 - accuracy: 0.9760 - val_loss: 0.0244 - val_accuracy: 0.9908
# Epoch 52/100
# 12/12 [==============================] - 22s 2s/step - loss: 0.0504 - accuracy: 0.9867 - val_loss: 0.0452 - val_accuracy: 0.9908
# Epoch 53/100
# 12/12 [==============================] - 22s 2s/step - loss: 0.0927 - accuracy: 0.9733 - val_loss: 0.0733 - val_accuracy: 0.9817
# Epoch 54/100
# 12/12 [==============================] - 22s 2s/step - loss: 0.1412 - accuracy: 0.9600 - val_loss: 0.0170 - val_accuracy: 1.0000
# Epoch 55/100
# 12/12 [==============================] - 22s 2s/step - loss: 0.1421 - accuracy: 0.9547 - val_loss: 0.0151 - val_accuracy: 1.0000
# Epoch 56/100
# 12/12 [==============================] - 22s 2s/step - loss: 0.1260 - accuracy: 0.9707 - val_loss: 0.0390 - val_accuracy: 0.9908
# Epoch 57/100
# 12/12 [==============================] - 22s 2s/step - loss: 0.0776 - accuracy: 0.9893 - val_loss: 0.0136 - val_accuracy: 1.0000
# Epoch 58/100
# 12/12 [==============================] - 22s 2s/step - loss: 0.0702 - accuracy: 0.9787 - val_loss: 0.0152 - val_accuracy: 1.0000
# Epoch 59/100
# 12/12 [==============================] - 22s 2s/step - loss: 0.0664 - accuracy: 0.9760 - val_loss: 0.1960 - val_accuracy: 0.9541
# Epoch 60/100
# 12/12 [==============================] - 21s 2s/step - loss: 0.0862 - accuracy: 0.9733 - val_loss: 0.1482 - val_accuracy: 0.9541
# Epoch 61/100
# 12/12 [==============================] - 21s 2s/step - loss: 0.1914 - accuracy: 0.9573 - val_loss: 0.0890 - val_accuracy: 0.9725
# Epoch 62/100
# 12/12 [==============================] - 21s 2s/step - loss: 0.1383 - accuracy: 0.9600 - val_loss: 0.0220 - val_accuracy: 1.0000
# Epoch 63/100
# 12/12 [==============================] - 20s 2s/step - loss: 0.1765 - accuracy: 0.9547 - val_loss: 0.0890 - val_accuracy: 0.9725
# Epoch 64/100
# 12/12 [==============================] - 20s 2s/step - loss: 0.0848 - accuracy: 0.9840 - val_loss: 0.0089 - val_accuracy: 1.0000
# Epoch 65/100
#  8/12 [===================>..........] - ETA: 6s - loss: 0.0763 - accuracy: 0.9805

# %%
# Save the trained model
model.save('Mediterranean.h5')

# %%
# Plot the accuracy and loss curves
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs_range = range(epochs)

# %%
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
plt.subplot(2, 1, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels
import matplotlib.pyplot as plt

# Generate predictions and compute the confusion matrix
Y_pred = model.predict(val_generator)
y_pred = np.argmax(Y_pred, axis=1)
cm = confusion_matrix(val_generator.classes, y_pred)

# Define class labels
class_names = ['Baklava', 'Belgian Waffle', 'Bibimbap', 'Butter Chicken', 'Cheesecake', 'Chicken Biriyani', 
    'Chicken Satay', 'Chilli prawn', 'Chole bhatore', 'Crab asparagus', 'Croissant', 'Dumplings', 
    'Egg Tart', 'Harissa fish', 'Idli', 'Lasagna', 'Masala Dosa', 'Natillas', 'Nigiri Shrimp', 'oyster stir', 'Paneer tikka masala', 'Pav bhaji', 'Penne Alfredo', 'Peri peri Chicken', 
    'Pizza', 'Poha', 'Pretzels', 'Rajma', 'Ratatouille', 'Shoyu Ramen', 'Spaghetti', 
    'Teriyaki Mushroom', 'Tiramisu', 'Tteokbokki', 'Zesty salmon']


# Plot the confusion matrix
fig, ax = plt.subplots()
im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)
# Set the x-axis and y-axis labels
ax.set(xticks=np.arange(cm.shape[1]),
       yticks=np.arange(cm.shape[0]),
       xticklabels=class_names, yticklabels=class_names,
       xlabel='Predicted label', ylabel='True label')
# Rotate the x-axis labels to vertical orientation
plt.setp(ax.get_xticklabels(), rotation=90, ha="right",
         rotation_mode="anchor")
# Loop over the data and annotate each cell with its value
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], 'd'),
                ha="center", va="center",
                color="white" if cm[i, j] > cm.max() / 2. else "black")
# Add a title to the plot
ax.set_title("Confusion matrix")
fig.tight_layout()
plt.show()

# %%
# Get the accuracy from the history object
accuracy = history.history['accuracy'][-1]

# Print the accuracy to the console
print("Accuracy: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy: 99.73%
